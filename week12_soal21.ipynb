# %% [markdown]
# <a href="https://colab.research.google.com/github/Aisnya975/problemset_aisyah_033/blob/main/week12_soal21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Core 1: Dedicated khusus untuk Network Polling (tanpa OS Interrupt)
FUNCTION Core1_NetworkPoller():
    WHILE True:
        # Baca langsung dari register Memory Card (NIC) bypass Kernel
        packet = NIC_Hardware_Queue.poll()
        IF packet:
            SharedMemoryRingBuffer.push(packet)

# Core 2: Dedicated khusus untuk Trading Logic
FUNCTION Core2_TradingEngine():
    WHILE True:
        data = SharedMemoryRingBuffer.pop()
        decision = Algorithm(data)
        IF decision == BUY:
            SendOrder(decision)
